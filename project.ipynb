# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# #### Reading all the data into a dictionary

# %%
file_1996_97 = pd.read_csv("data/seasons/1996-97.csv")
file_1996_97.info()
file_1996_97.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      574 non-null    int64
#  1   Player  574 non-null    object
#  2   Pos     574 non-null    object
#  3   Age     574 non-null    int64
#  4   Tm      574 non-null    object
#  5   G       574 non-null    int64
#  6   GS      574 non-null    int64
#  7   MP      574 non-null    int64
#  8   FG      574 non-null    int64
#  9   FGA     574 non-null    int64
#  10  FG%     571 non-null    float64
#  11  3P      574 non-null    int64
#  12  3PA     574 non-null    int64
#  13  3P%     461 non-null    float64
#  14  2P      574 non-null    int64
#  15  2PA     574 non-null    int64
#  16  2P%     571 non-null    float64
#  17  eFG%    571 non-null    float64
#  18  FT      574 non-null    int64
#  19  FTA     574 non-null    int64
#  20  FT%     545 non-null    float64
#  21  ORB     574 non-null    int64
#  22  DRB     574 non-null    int64
#  23  TRB     574 non-null    int64
#  24  AST     574 non-null    int64
#  25  STL     574 non-null    int64
#  26  BLK     574 non-null    int64
#  27  TOV     574 non-null    int64
#  28  PF      574 non-null    int64
#  29  PTS     574 non-null    int64
# dtypes: float64(5), int64(22), object(3)
# memory usage: 134.7+ KB
#    Rk                         Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 0   1   Mahmoud Abdul-Rauf\abdulma02  PG   27  SAC  75  51  2131  411   924
# 1   2  Shareef Abdur-Rahim\abdursh01  PF   20  VAN  80  71  2802  550  1214
# 2   3       Rafael Addison\addisra01  SF   32  CHH  41   3   355   49   122
# 3   4       Cory Alexander\alexaco01  PG   23  SAS  80   6  1454  194   490
# 4   5         Jerome Allen\allenje01  SG   24  TOT  76   1   943   78   221
#
#    ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  ...  0.846   16  106  122  189   56    6  119  174  1031
# 1  ...  0.746  216  339  555  175   79   79  225  199  1494
# 2  ...  0.786   19   26   45   34    8    3   17   52   128
# 3  ...  0.736   29   94  123  254   82   16  146  148   577
# 4  ...  0.583   25   73   98  152   31    4   69   84   228
#
# [5 rows x 30 columns]

# %%
len(pd.read_csv(file_path))
# Out:
# 686

# %%
seasons_dict = {}
for i in range(42):
    key = str(1979 + i) + "-" + str(80+i)[-2:]
    file_path = "data/seasons/" + key + ".csv"
    season_df = pd.read_csv(file_path)
    year_array = np.array([key for x in range(len(season_df))])
    season_df["Year"] = year_array
    seasons_dict[key] = season_df
    
seasons_dict[key]
# Out:
#       Rk                       Player Pos  Age   Tm   G  GS    MP   FG  FGA  \
# 0      1   Precious Achiuwa\achiupr01  PF   21  MIA  55   3   683  112  207
# 1      2       Jaylen Adams\adamsja01  PG   24  MIL   7   0    18    1    8
# 2      3       Steven Adams\adamsst01   C   27  NOP  57  57  1581  189  305
# 3      4        Bam Adebayo\adebaba01   C   23  MIA  56  56  1877  405  712
# 4      5  LaMarcus Aldridge\aldrila01   C   35  TOT  26  23   674  140  296
# ..   ...                          ...  ..  ...  ...  ..  ..   ...  ...  ...
# 681  527       Delon Wright\wrighde01  PG   28  SAC  17   0   365   46  108
# 682  528     Thaddeus Young\youngth01  PF   32  CHI  58  17  1400  319  552
# 683  529         Trae Young\youngtr01  PG   22  ATL  54  54  1849  413  962
# 684  530        Cody Zeller\zelleco01   C   28  CHO  39  20   814  143  262
# 685  531        Ivica Zubac\zubaciv01   C   23  LAC  64  25  1437  232  359
#
#      ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS     Year
# 0    ...   70  127  197   27   18   26   41   88   277  2020-21
# 1    ...    0    3    3    2    0    0    0    1     2  2020-21
# 2    ...  212  294  506  109   54   37   78  113   437  2020-21
# 3    ...  128  382  510  291   61   61  151  126  1073  2020-21
# 4    ...   19   99  118   49   11   29   27   47   352  2020-21
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...   ...      ...
# 681  ...   13   37   50   36   21    3   13   17   133  2020-21
# 682  ...  141  214  355  246   66   32  115  137   702  2020-21
# 683  ...   35  177  212  516   48   11  228  100  1365  2020-21
# 684  ...  100  168  268   74   23   14   40   91   356  2020-21
# 685  ...  175  292  467   80   24   56   74  167   587  2020-21
#
# [686 rows x 31 columns]

# %%
halloffame = pd.read_csv("data/halloffame.csv")
halloffame.info()
halloffame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          199 non-null    int64
#  1   Inductees     199 non-null    object
#  2   Pos.          198 non-null    object
#  3   Achievements  199 non-null    object
#  4   Ref.          191 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 7.9+ KB
#      Year            Inductees Pos.  \
# 0    1959          Chuck Hyatt    G
# 1    1959        Hank Luisetti    F
# 2    1959         George Mikan    C
# 3    1959        John Schommer    G
# 4    1960           Vic Hanson    G
# ..    ...                  ...  ...
# 194  2019          Bobby Jones    F
# 195  2019      Sidney Moncrief    G
# 196  2019           Jack Sikma  F/C
# 197  2019  Teresa Weatherspoon    G
# 198  2019        Paul Westphal    G
#
#                                           Achievements Ref.
# 0    National championship (Pittsburgh, 1928, 1930)...  [3]
# 1    3 Pacific Coast Conference championships (Stan...  [4]
# 2    All-America (DePaul, 1944–45); All-NBA First-T...  [5]
# 3    Big Ten Championships (Chicago, 1907–09); All-...  [6]
# 4    Helms Foundation Championship (Syracuse, 1926)...  [7]
# ..                                                 ...  ...
# 194  NBA champion (1983)4× NBA All-Star (1977, 1978...  NaN
# 195  5x NBA All-Star (1982–1986)All-NBA First Team ...  NaN
# 196  NBA champion (1979)7× NBA All-Star (1979–1985)...  NaN
# 197  First WNBA player with 1,000 points and 1,000 ...  NaN
# 198  NBA champion (1974)5× NBA All-Star (1977–1981)...  NaN
#
# [199 rows x 5 columns]

# %%
# Exclude shortened seasons (1998-99, 2011-12, and 2019-20)

# %%
# halloffame_1 = halloffame[~halloffame['Year'].isin([1998, 1999, 2011, 2012, 2019, 2020])]
# halloffame_1

# %%
# Player data since 1976 NBA-ABA Merger

# %%
# halloffame_2 = halloffame_1[halloffame_1['Year'] > 1976]
# halloffame_2

# %%
# Eliminate outliers in dataset
# Too few games played
# Too few minutes played

# %%
file_1996_97_1 = file_1996_97[file_1996_97['G'] >= 40]
file_1996_97_1 = file_1996_97_1[file_1996_97_1['MP'] >= 10]
file_1996_97_1
# Out:
#       Rk                         Player Pos  Age   Tm   G  GS    MP   FG  \
# 0      1   Mahmoud Abdul-Rauf\abdulma02  PG   27  SAC  75  51  2131  411
# 1      2  Shareef Abdur-Rahim\abdursh01  PF   20  VAN  80  71  2802  550
# 2      3       Rafael Addison\addisra01  SF   32  CHH  41   3   355   49
# 3      4       Cory Alexander\alexaco01  PG   23  SAS  80   6  1454  194
# 4      5         Jerome Allen\allenje01  SG   24  TOT  76   1   943   78
# ..   ...                            ...  ..  ...  ...  ..  ..   ...  ...
# 565  435              Joe Wolf\wolfjo01   C   32  MIL  56   7   525   40
# 566  436            David Wood\woodda01  PF   32  MIL  46   0   240   20
# 568  438      Lorenzen Wright\wrighlo02   C   21  LAC  77  51  1936  236
# 569  439       Sharone Wright\wrighsh01   C   24  TOR  60  28  1009  161
# 570  440         George Zídek\zidekge01   C   23  TOT  52   2   376   49
#
#       FGA  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0     924  ...  0.846   16  106  122  189   56    6  119  174  1031
# 1    1214  ...  0.746  216  339  555  175   79   79  225  199  1494
# 2     122  ...  0.786   19   26   45   34    8    3   17   52   128
# 3     490  ...  0.736   29   94  123  254   82   16  146  148   577
# 4     221  ...  0.583   25   73   98  152   31    4   69   84   228
# ..    ...  ...    ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 565    89  ...  0.737   32   80  112   20   14   11   14  105    95
# 566    38  ...  0.667    5   22   27   13    7    6    6   36    57
# 568   491  ...  0.587  206  265  471   49   48   60   79  211   561
# 569   403  ...  0.511   79  107  186   28   15   50   93  146   390
# 570   118  ...  0.789   35   51   86   14    5    3   27   61   143
#
# [337 rows x 30 columns]

# %%
for key in seasons_dict.keys():
    temp_df = seasons_dict[key]
    temp_df = temp_df[temp_df['G'] >= 40]
    temp_df = temp_df[temp_df['MP'] >= 10]
    seasons_dict[key] = temp_df.reset_index()
    
seasons_dict[key]
# Out:
#      index   Rk                              Player    Pos  Age   Tm   G  GS  \
# 0        0    1          Precious Achiuwa\achiupr01     PF   21  MIA  55   3
# 1        2    3              Steven Adams\adamsst01      C   27  NOP  57  57
# 2        3    4               Bam Adebayo\adebaba01      C   23  MIA  56  56
# 3        8    7  Nickeil Alexander-Walker\alexani01     SG   22  NOP  41  10
# 4        9    8             Grayson Allen\allengr01     SG   25  MEM  48  36
# ..     ...  ...                                 ...    ...  ...  ...  ..  ..
# 279    669  519           Zion Williamson\willizi01     PF   20  NOP  57  57
# 280    679  527              Delon Wright\wrighde01  SG-PG   28  TOT  53  31
# 281    682  528            Thaddeus Young\youngth01     PF   32  CHI  58  17
# 282    683  529                Trae Young\youngtr01     PG   22  ATL  54  54
# 283    685  531               Ivica Zubac\zubaciv01      C   23  LAC  64  25
#
#        MP   FG  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS     Year
# 0     683  112  ...   70  127  197   27   18   26   41   88   277  2020-21
# 1    1581  189  ...  212  294  506  109   54   37   78  113   437  2020-21
# 2    1877  405  ...  128  382  510  291   61   61  151  126  1073  2020-21
# 3     851  158  ...   10  116  126   81   40   21   57   77   420  2020-21
# 4    1227  173  ...   18  137  155  103   45    8   47   71   528  2020-21
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...      ...
# 279  1876  588  ...  148  256  404  204   51   36  150  133  1528  2020-21
# 280  1417  182  ...   50  164  214  217   79   22   61   62   507  2020-21
# 281  1400  319  ...  141  214  355  246   66   32  115  137   702  2020-21
# 282  1849  413  ...   35  177  212  516   48   11  228  100  1365  2020-21
# 283  1437  232  ...  175  292  467   80   24   56   74  167   587  2020-21
#
# [284 rows x 32 columns]

# %% [markdown]
# #### Splitting up player names and player IDs

# %%
player_96_97 = [file_1996_97["Player"][x].split("\\") for x in range(len(file_1996_97))]
file_1996_97["Player_ID"] = [x[1] for x in player_96_97]
file_1996_97["Player"] = [x[0] for x in player_96_97]
file_1996_97
# Out:
#       Rk                 Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1     Mahmoud Abdul-Rauf  PG   27  SAC  75  51  2131  411   924  ...
# 1      2    Shareef Abdur-Rahim  PF   20  VAN  80  71  2802  550  1214  ...
# 2      3         Rafael Addison  SF   32  CHH  41   3   355   49   122  ...
# 3      4         Cory Alexander  PG   23  SAS  80   6  1454  194   490  ...
# 4      5           Jerome Allen  SG   24  TOT  76   1   943   78   221  ...
# ..   ...                    ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 569  439         Sharone Wright   C   24  TOR  60  28  1009  161   403  ...
# 570  440           George Zídek   C   23  TOT  52   2   376   49   118  ...
# 571  440           George Zídek   C   23  CHH  36   2   288   33    85  ...
# 572  440           George Zídek   C   23  DEN  16   0    88   16    33  ...
# 573  441  Aleksandar Djordjevic  SG   29  POR   8   0    61    8    16  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Player_ID
# 0     16  106  122  189   56    6  119  174  1031  abdulma02
# 1    216  339  555  175   79   79  225  199  1494  abdursh01
# 2     19   26   45   34    8    3   17   52   128  addisra01
# 3     29   94  123  254   82   16  146  148   577  alexaco01
# 4     25   73   98  152   31    4   69   84   228  allenje01
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...        ...
# 569   79  107  186   28   15   50   93  146   390  wrighsh01
# 570   35   51   86   14    5    3   27   61   143  zidekge01
# 571   25   38   63    9    4    3   23   44    91  zidekge01
# 572   10   13   23    5    1    0    4   17    52  zidekge01
# 573    1    4    5    5    0    0    5    3    25  djordal01
#
# [574 rows x 31 columns]

# %%
for key in seasons_dict.keys():
    temp_df = seasons_dict[key]
    player_temp = [temp_df["Player"][x].split("\\") for x in range(len(temp_df))]
    temp_df["Player_ID"] = [x[1] for x in player_temp]
    temp_df["Player"] = [x[0] for x in player_temp]
    seasons_dict[key] = temp_df
    
# player_temp = [seasons_dict["1976-77"]["Player"][x].split("\\") for x in range(len(seasons_dict["1976-77"]))]
# player_temp
# seasons_dict["1976-77"]

# %% [markdown]
# #### Cleaning for Players who have been traded

# %%
player_id_96_97 = file_1996_97["Player_ID"]
duplicates = [x for x in np.unique(player_id_96_97) if len([y for y in player_id_96_97 if y==x]) > 1]
duplicates


file_1996_97[ (file_1996_97["Player_ID"] == "allenje01")  & (file_1996_97["Tm"] == "TOT")]

for name in duplicates:
    new_temp = file_1996_97[ (file_1996_97["Player_ID"] == name)  & (file_1996_97["Tm"] == "TOT")]
    file_1996_97 = file_1996_97[file_1996_97["Player_ID"] != name]
    file_1996_97 = pd.concat([new_temp, file_1996_97])

# %%
Sea_18_19 = seasons_dict["2018-19"]

player_id_18_19 = Sea_18_19["Player_ID"]
duplicates = [x for x in np.unique(player_id_18_19) if len([y for y in player_id_18_19 if y==x]) > 1]
duplicates
# Out:
# ['arizatr01',
#  'barneha02',
#  'bradlav01',
#  'bullore01',
#  'butleji01',
#  'chandty01',
#  'ennisja01',
#  'fraziti01',
#  'gasolma01',
#  'greenja01',
#  'hardati02',
#  'harrito02',
#  'hillge01',
#  'holidju01',
#  'hoodro01',
#  'jacksju01',
#  'johnsst04',
#  'johnsty01',
#  'jordade01',
#  'kanteen01',
#  'korveky01',
#  'linje01',
#  'macksh01',
#  'matthwe02',
#  'milescj01',
#  'muscami01',
#  'oubreke01',
#  'porteot01',
#  'riverau01',
#  'saricda01',
#  'scottmi01',
#  'seldewa01',
#  'shamela01',
#  'shumpim01',
#  'simmojo02',
#  'stausni01',
#  'templga01',
#  'wrighde01']

# %%
for key in seasons_dict:
    temp_df = seasons_dict[key]
    player_id_list = temp_df["Player_ID"]
    duplicates = [x for x in np.unique(player_id_list) if len([y for y in player_id_list if y==x]) > 1]
    for name in duplicates:
        new_temp = temp_df[ (temp_df["Player_ID"] == name)  & (temp_df["Tm"] == "TOT")]
        temp_df = temp_df[temp_df["Player_ID"] != name]
        temp_df = pd.concat([new_temp, temp_df])
    seasons_dict[key] = temp_df

# %%
Sea_18_19 = seasons_dict["2018-19"]

player_id_18_19 = Sea_18_19["Player_ID"]
duplicates = [x for x in np.unique(player_id_18_19) if len([y for y in player_id_18_19 if y==x]) > 1]
duplicates
# Out:
# []

# %% [markdown]
# #### Replacing Nan with 0s

# %%
for key in seasons_dict:
    seasons_dict[key] = seasons_dict[key].fillna(0)

# %% [markdown]
# #### Converting all stats into z scores

# %%
file_1996_97.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Player_ID'],
#       dtype='object')

# %%
import scipy.stats as spt

column_names_zscore = list(file_1996_97.columns[8:-2]) 
column_names_keep = list(file_1996_97.columns[:8]) + [file_1996_97.columns[-2] ] + [file_1996_97.columns[-1] ]
file_1996_97 = file_1996_97.fillna(0)

file_1996_97['Year'] = ["1996_97" for i in range(len(file_1996_97))]
column_names_keep

# new_df_96_97 = file_1996_97[column_names_keep]
# column_names_zscore[:-2]


for col in column_names_zscore[:-2]:
    col_name = col + "_zscore"
    new_df_96_97[col_name] = spt.zscore(file_1996_97[col])

# new_df_96_97.columns
# for col in column_names_zscore[-2:]:
#     col_name = col + "_zscore"
#     new_df_96_97[col_name] = file_1996_97[col]
# column_names_zscore
column_names_keep
# Out:
# ['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'Player_ID', 'Year']

# %%
zscores_dict = {}
for key in seasons_dict:
    new_temp_df = seasons_dict[key][column_names_keep]
    for col in column_names_zscore:
        col_name = col + "_zscore"
        new_temp_df[col_name] = spt.zscore(seasons_dict[key][col])
    zscores_dict[key] = new_temp_df
zscores_dict["2005-06"]

# spt.zscore(seasons_dict["1979-80"]["FG"])
# column_names_zscore
# Out:
# <ipython-input-867-88dfa811db85>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_temp_df[col_name] = spt.zscore(seasons_dict[key][col])
#       Rk            Player    Pos  Age   Tm   G  GS    MP  Player_ID     Year  \
# 332  439      Chris Wilcox   C-PF   23  TOT  77  24  1529  wilcoch01  2005-06
# 323  430       Earl Watson     PG   26  TOT  70  10  1578  watsoea01  2005-06
# 295  391  Wally Szczerbiak     SF   28  TOT  72  71  2729  szczewa02  2005-06
# 289  383   Peja Stojaković     SF   28  TOT  71  71  2601  stojape01  2005-06
# 268  355        Jalen Rose  SF-SG   33  TOT  72  45  1983   roseja01  2005-06
# ..   ...               ...    ...  ...  ...  ..  ..   ...        ...      ...
# 338  446    Jason Williams     PG   30  MIA  59  56  1874  willija02  2005-06
# 339  448   Marvin Williams     PF   19  ATL  79   7  1952  willima02  2005-06
# 340  449       Mo Williams     PG   23  MIL  58  12  1531  willima01  2005-06
# 341  452      Qyntel Woods     SF   24  NYK  49  16  1013  woodsqy01  2005-06
# 344  457   Lorenzen Wright      C   30  MEM  78  58  1689  wrighlo02  2005-06
#
#      ...  FT%_zscore  ORB_zscore  DRB_zscore  TRB_zscore  AST_zscore  \
# 332  ...    0.071441    0.636066    0.580552    0.627066   -0.671091
# 323  ...   -0.448522   -0.921442   -0.575718   -0.715293    0.975333
# 295  ...    1.603474   -0.043273    0.170735    0.110365    0.447366
# 289  ...    1.770604   -0.010134    0.902551    0.653700   -0.087548
# 268  ...    0.517123   -0.855165   -0.217128   -0.432971    0.225064
# ..   ...         ...         ...         ...         ...         ...
# 338  ...    1.324922   -1.219688   -0.583036   -0.816502    0.961439
# 339  ...    0.210717    0.702343    0.353689    0.483242   -0.594675
# 340  ...    1.167076   -0.822026   -0.729399   -0.795195    0.565464
# 341  ...   -0.736358   -0.590057   -0.487900   -0.544834   -0.705826
# 344  ...   -1.488447    1.033728    0.295143    0.547164   -0.698879
#
#      STL_zscore  BLK_zscore  TOV_zscore  PF_zscore  PTS_zscore
# 332   -0.540445    0.003925   -0.437598   0.386505   -0.141818
# 323    0.497025   -0.612161    0.640835  -0.015522   -0.147802
# 295   -0.332951   -0.381129    0.640835  -0.166282    1.334186
# 289   -0.184741   -0.612161    0.084768   0.185492    1.182597
# 268   -0.629372   -0.535151    0.286974  -0.065775    0.378773
# ..          ...         ...         ...        ...         ...
# 338    0.052395   -0.740513    0.034216  -0.987086    0.061631
# 339   -0.095815   -0.252778   -0.252242   1.123554   -0.050066
# 340    0.022753   -0.689172    0.118469  -0.233286    0.011766
# 341   -0.570087   -0.535151   -0.622954  -1.070842   -0.734214
# 344    0.022753    0.311968   -0.521851   0.688025   -0.484889
#
# [327 rows x 32 columns]

# %% [markdown]
# #### Getting all player names and IDs

# %%
player_names_id_df = pd.DataFrame(columns = ["Player", "Player_ID"])
player_names_id_df
for df in zscores_dict.values():
    temp_df = df[["Player", "Player_ID"]]
    player_names_id_df = pd.concat([player_names_id_df,temp_df])

# %%
def string_filter(string):
    word = filter(str.isalnum, string)
    word = "".join(word)
    return word.lower()

# %%
name_id_df = player_names_id_df.drop_duplicates().reset_index()[["Player", "Player_ID"]]
# name_id_df["Player"] = name_id_df["Player"].appl
player_names = name_id_df["Player"].apply(string_filter)
name_id_df["Player"] = player_names
player_to_ID = {}
for i in range(len(name_id_df["Player"])):
    player_to_ID[name_id_df["Player"][i]] = name_id_df["Player_ID"][i]
player_to_ID


ID_to_Player = {}
for i in range(len(name_id_df["Player"])):
    ID_to_Player[name_id_df["Player_ID"][i]] = name_id_df["Player"][i]
    
ID_to_Player
# Out:
# ['abdelal01',
#  'abdulka01',
#  'abdulma02',
#  'abdulta01',
#  'abdursh01',
#  'abernto01',
#  'abrinal01',
#  'achiupr01',
#  'acresma01',
#  'acyqu01',
#  'adamsal01',
#  'adamsha01',
#  'adamsmi01',
#  'adamsst01',
#  'addisra01',
#  'adebaba01',
#  'adrieje01',
#  'afflaar01',
#  'aguirma01',
#  'aingeda01',
#  'ajincal01',
#  'alarima01',
#  'aldemfu01',
#  'aldrico01',
#  'aldrila01',
#  'aleksch01',
#  'alexaco01',
#  'alexaco02',
#  'alexajo01',
#  'alexani01',
#  'alexavi01',
#  'alforst01',
#  'allengr01',
#  'allenja01',
#  'allenje01',
#  'allenla01',
#  'allenma01',
#  'allenra01',
#  'allenra02',
#  'allento01',
#  'alstode01',
#  'alstora01',
#  'amaecjo01',
#  'amayaas01',
#  'aminual01',
#  'amundlo01',
#  'anderal01',
#  'anderch01',
#  'anderda03',
#  'anderde01',
#  'andergr01',
#  'anderja01',
#  'anderjj01',
#  'anderju01',
#  'anderke01',
#  'anderky01',
#  'anderni01',
#  'anderri01',
#  'anderro01',
#  'anderry01',
#  'andersh01',
#  'anderwi01',
#  'anslemi01',
#  'anstech01',
#  'antetgi01',
#  'antetth01',
#  'anthoca01',
#  'anthogr01',
#  'anthojo01',
#  'anticpe01',
#  'anunoog01',
#  'araujra01',
#  'architi01',
#  'arcidry01',
#  'arenagi01',
#  'arizatr01',
#  'armstbj01',
#  'armstbr01',
#  'armstda01',
#  'armsthi01',
#  'arroyca01',
#  'artesro01',
#  'arthuda01',
#  'asikom01',
#  'askewvi01',
#  'askinke01',
#  'atkinch01',
#  'augmost01',
#  'augusdj01',
#  'austiis01',
#  'avdijde01',
#  'aventan01',
#  'averywi01',
#  'awtrede01',
#  'ayongu01',
#  'aytonde01',
#  'azubuke01',
#  'babbilu01',
#  'bacondw01',
#  'bagarda01',
#  'baglejo01',
#  'baglema01',
#  'baileja01',
#  'baileth01',
#  'baileto01',
#  'bakerro01',
#  'bakervi01',
#  'balkmre01',
#  'ballagr01',
#  'ballla01',
#  'balllo01',
#  'bambamo01',
#  'banede01',
#  'banksge01',
#  'banksma01',
#  'bannike01',
#  'bantomi01',
#  'barbole01',
#  'bareajo01',
#  'bargnan01',
#  'barklch01',
#  'barneha02',
#  'barnema02',
#  'barrerj01',
#  'barroda01',
#  'barroea01',
#  'barrybr01',
#  'barryjo01',
#  'barryri01',
#  'bartowi01',
#  'bassbr01',
#  'bastoma01',
#  'batesbi01',
#  'bateske01',
#  'batises01',
#  'batismi01',
#  'battish01',
#  'battito01',
#  'battljo01',
#  'battlke01',
#  'battoda01',
#  'batumni01',
#  'baxtelo01',
#  'bayleje01',
#  'baynear01',
#  'bazemke01',
#  'bazleda01',
#  'bealbr01',
#  'beaslma01',
#  'beaslmi01',
#  'beaubro01',
#  'beckco01',
#  'bedfowi01',
#  'belinma01',
#  'bellch01',
#  'belljo01',
#  'bellra01',
#  'bembrde01',
#  'bendedr01',
#  'bendejo01',
#  'benjabe01',
#  'benjaco01',
#  'bennean01',
#  'bennema01',
#  'benneto01',
#  'bennewi01',
#  'benoida01',
#  'bensoke01',
#  'berryri01',
#  'berrywa01',
#  'bertada01',
#  'beshode01',
#  'besttr01',
#  'beverpa01',
#  'beysa01',
#  'bibbyhe01',
#  'bibbymi01',
#  'biedran01',
#  'billuch01',
#  'birchkh01',
#  'birdla01',
#  'birdsot01',
#  'bitadgo01',
#  'biyombi01',
#  'bjeline01',
#  'blabuw01',
#  'blackco01',
#  'blackro01',
#  'blackta01',
#  'blairde01',
#  'blakean01',
#  'blakest01',
#  'blankla01',
#  'blatcan01',
#  'blaylmo01',
#  'bledser01',
#  'blounco01',
#  'blounma01',
#  'blumera01',
#  'boganke01',
#  'bogdabo01',
#  'bogdabo02',
#  'boguemu01',
#  'bogutan01',
#  'boldejo01',
#  'bolma01',
#  'bondwa01',
#  'bongais01',
#  'bonnean01',
#  'bonnema01',
#  'bookede01',
#  'booketr01',
#  'boonejo01',
#  'boonero01',
#  'boothca01',
#  'boozeca01',
#  'borchcu01',
#  'boshch01',
#  'bosweto01',
#  'bouchch01',
#  'bowdlca01',
#  'bowenbr01',
#  'bowenry01',
#  'bowiean01',
#  'bowiesa01',
#  'bowmaky01',
#  'boykiea01',
#  'boynewi01',
#  'bradlav01',
#  'bradlch01',
#  'bradldu01',
#  'bradlmi01',
#  'bradlsh01',
#  'bradlto01',
#  'braggma01',
#  'brancad01',
#  'brandel01',
#  'brandte01',
#  'bransbr01',
#  'bratzmi01',
#  'breauti01',
#  'bremejr01',
#  'breuera01',
#  'breweco01',
#  'breweji01',
#  'brewero01',
#  'brewero02',
#  'brezepr01',
#  'brickfr01',
#  'bridgju01',
#  'bridgmi01',
#  'bridgmi02',
#  'bristal01',
#  'brockjo01',
#  'broekry01',
#  'brogaji01',
#  'brogdma01',
#  'brookaa01',
#  'brookdi01',
#  'brookke01',
#  'brookma01',
#  'brookmi01',
#  'brooksc01',
#  'brownbo02',
#  'brownbr01',
#  'brownch01',
#  'brownde01',
#  'brownde02',
#  'brownde03',
#  'brownde04',
#  'brownfr01',
#  'brownja02',
#  'brownke01',
#  'brownkw01',
#  'brownma02',
#  'brownmi01',
#  'brownpj01',
#  'brownra02',
#  'brownri01',
#  'brownsh01',
#  'brownst02',
#  'brownti01',
#  'brownto01',
#  'browntr01',
#  'brunsja01',
#  'brunsri01',
#  'brussni01',
#  'bryanjo01',
#  'bryanko01',
#  'bryanma01',
#  'bryanth01',
#  'bryanwa01',
#  'buckngr01',
#  'bucknqu01',
#  'budinch01',
#  'buechju01',
#  'buforro01',
#  'bullama01',
#  'bullore01',
#  'burkepa01',
#  'burketr01',
#  'burksal01',
#  'burksan01',
#  'burresc01',
#  'burroju01',
#  'burtowi01',
#  'burttst01',
#  'busedo01',
#  'butleca01',
#  'butleja01',
#  'butleji01',
#  'butlemi02',
#  'butlera01',
#  'bynuman01',
#  'bynumwi01',
#  'byrnema01',
#  'cabarza01',
#  'caffeja01',
#  'cagemi01',
#  'calatni01',
#  'caldejo01',
#  'caldwad01',
#  'caldwke01',
#  'callori01',
#  'calvima01',
#  'cambrde01',
#  'cambyma01',
#  'campafa01',
#  'campbel01',
#  'campbto01',
#  'canaais01',
#  'capelca01',
#  'caracde01',
#  'cardibr01',
#  'carliri01',
#  'carnero01',
#  'carran01',
#  'carrau01',
#  'carrch01',
#  'carrco01',
#  'carrke01',
#  'carrml01',
#  'carrode01',
#  'carrojo01',
#  'carroma01',
#  'cartean01',
#  'cartebu01',
#  'carteho01',
#  'carteje01',
#  'cartemi01',
#  'cartere01',
#  'cartevi01',
#  'cartewe01',
#  'cartwbi01',
#  'carusal01',
#  'cassesa01',
#  'casspom01',
#  'catchha01',
#  'catlete01',
#  'catoke01',
#  'cattabo01',
#  'caulewi01',
#  'causwdu01',
#  'cavenro01',
#  'cebalce01',
#  'chalmma01',
#  'chambto01',
#  'chandty01',
#  'chandwi01',
#  'chanedo01',
#  'chapmre01',
#  'cheanca01',
#  'cheekma01',
#  'cheniph01',
#  'chievde01',
#  'chilcpe01',
#  'childch01',
#  'childjo01',
#  'choneji01',
#  'chrisdo01',
#  'chrisma01',
#  'chrisse01',
#  'clarkbr01',
#  'clarkca01',
#  'clarkea01',
#  'clarkga01',
#  'clarkia01',
#  'clarkjo01',
#  'clarkke01',
#  'clavevi01',
#  'claxtsp01',
#  'cleamji01',
#  'cleavma01',
#  'closske01',
#  'coffeam01',
#  'cofferi01',
#  'cofiefr01',
#  'colembe01',
#  'colemde01',
#  'coleno01',
#  'colesbi01',
#  'collida01',
#  'collido02',
#  'collija02',
#  'collija03',
#  'collija04',
#  'collijo01',
#  'collima01',
#  'collini01',
#  'colliza01',
#  'coltest01',
#  'combsle01',
#  'comegda01',
#  'conlemi01',
#  'conloma01',
#  'connapa01',
#  'connele01',
#  'cookan01',
#  'cookbr01',
#  'cookda01',
#  'cookda02',
#  'cookje01',
#  'cookqu01',
#  'coopedu01',
#  'coopemi01',
#  'coopewa01',
#  'copelch01',
#  'copelho01',
#  'corbity01',
#  'corchch01',
#  'corzida01',
#  'courtjo01',
#  'couside01',
#  'covinro01',
#  'cowenda01',
#  'crabbal01',
#  'craigto01',
#  'crawfch01',
#  'crawfja01',
#  'crawfjo02',
#  'crissch01',
#  'crittja01',
#  'croshau01',
#  'crossru01',
#  'crottjo01',
#  'crowdco01',
#  'crowdja01',
#  'culveja01',
#  'cummipa01',
#  'cummite01',
#  'cummivo01',
#  'cunnida01',
#  'cunnija01',
#  'curetea01',
#  'curlebi01',
#  'curryde01',
#  'curryed01',
#  'currymi01',
#  'curryse01',
#  'curryst01',
#  'dailequ01',
#  'dalemsa01',
#  'dampier01',
#  'dandrbo01',
#  'daniean01',
#  'daniell01',
#  'daniema01',
#  'danietr01',
#  'danilsa01',
#  'dantlad01',
#  'dareyi01',
#  'daughbr01',
#  'davidko01',
#  'daviebr01',
#  'davisan01',
#  'davisan02',
#  'davisba01',
#  'davisbr01',
#  'davisbr02',
#  'davisch02',
#  'davisda01',
#  'davisde01',
#  'davised01',
#  'davisem01',
#  'davisgl01',
#  'davishu01',
#  'davisjo01',
#  'davisjo02',
#  'davisma02',
#  'davisri01',
#  'davisro01',
#  'daviste01',
#  'daviste02',
#  'daviswa03',
#  'dawkida01',
#  'dawkijo01',
#  'dawkipa01',
#  'dayeau01',
#  'dayeda01',
#  'dayto01',
#  'declean01',
#  'decolna01',
#  'dedmode01',
#  'deherte01',
#  'dekkesa01',
#  'delanma01',
#  'delebi01',
#  'delfica01',
#  'delkto01',
#  'dellama01',
#  'delnevi01',
#  'demicla01',
#  'denglu01',
#  'dennake01',
#  'derozde01',
#  'diallch01',
#  'diallha01',
#  'diawaya01',
#  'diawbo01',
#  'dickada01',
#  'dickemi01',
#  'dienetr01',
#  'dienggo01',
#  'dietrco01',
#  'dinwisp01',
#  'dioguik01',
#  'diopde01',
#  'divacvl01',
#  'divindo01',
#  'dixonju01',
#  'doleami01',
#  'donalja01',
#  'doncilu01',
#  'donovbi01',
#  'doolike01',
#  'dorsejo01',
#  'dorsety01',
#  'dortlu01',
#  'dotsoda01',
#  'doubyqu01',
#  'douglch01',
#  'dougljo01',
#  'douglle01',
#  'douglsh01',
#  'douglto01',
#  'doumbse01',
#  'doziepj01',
#  'dragigo01',
#  'dreilgr01',
#  'drewbr01',
#  'drewjo01',
#  'drewla01',
#  'drexlcl01',
#  'drobnpr01',
#  'drumman01',
#  'duckwke01',
#  'dudlech02',
#  'dudleja01',
#  'duerote01',
#  'duhonch01',
#  'dumarjo01',
#  'dumasri02',
#  'dumasto01',
#  'duncati01',
#  'dunlemi01',
#  'dunlemi02',
#  'dunnkr01',
#  'dunntr01',
#  'duprero01',
#  'duranke01',
#  'durenjo01',
#  'durhapa01',
#  'durrade01',
#  'eacklle01',
#  'earlac01',
#  'eatonma01',
#  'eavesje01',
#  'edmonke01',
#  'edneyty01',
#  'edwaran01',
#  'edwarbl01',
#  'edwarfr01',
#  'edwarja01',
#  'edwarjo01',
#  'edwarke01',
#  'ehlocr01',
#  'eisleho01',
#  'ekeziob01',
#  'elamikh01',
#  'eliema01',
#  'ellinwa01',
#  'elliobo01',
#  'elliose01',
#  'ellisbo02',
#  'ellisda01',
#  'ellisha01',
#  'ellisla01',
#  'ellisle02',
#  'ellismo01',
#  'ellispe01',
#  'elmorle01',
#  'elsonfr01',
#  'elyme01',
#  'embiijo01',
#  'englech01',
#  'engliaj01',
#  'englial01',
#  'engliki01',
#  'ennisja01',
#  'ennisty01',
#  'erdense01',
#  'ervinju01',
#  'eschmev01',
#  'eubandr01',
#  'evansbr01',
#  'evansja01',
#  'evansje01',
#  'evansma01',
#  'evansmi01',
#  'evansre01',
#  'evansty01',
#  'ewingda01',
#  'ewingpa01',
#  'exumda01',
#  'eyengch01',
#  'ezelife01',
#  'farieke01',
#  'farmajo01',
#  'farmeto01',
#  'favorde01',
#  'feickja01',
#  'feitlda01',
#  'feldeka01',
#  'feliccr01',
#  'feltora01',
#  'fergute01',
#  'fernabr01',
#  'fernaru01',
#  'fernser01',
#  'ferredu01',
#  'ferreyo01',
#  'ferryda01',
#  'fesenky01',
#  'fieldke01',
#  'fieldla01',
#  'finlemi01',
#  'finnedo01',
#  'fishede01',
#  'fizerma01',
#  'flemive01',
#  'flowebr01',
#  'floydsl01',
#  'flynnjo01',
#  'forbebr01',
#  'forbega01',
#  'fordal02',
#  'fordch01',
#  'forddo01',
#  'fordph01',
#  'fordtj01',
#  'fortsda01',
#  'fostegr01',
#  'fosteje01',
#  'fostero01',
#  'fournev01',
#  'foxde01',
#  'foxri01',
#  'foyera01',
#  'foylead01',
#  'frahmri01',
#  'francst01',
#  'frankte01',
#  'fraziti01',
#  'fredean01',
#  'fredeji01',
#  'freeljo01',
#  'freewo01',
#  'fryech01',
#  'fulleto02',
#  'fultzma01',
#  'fundela01',
#  'furlote01',
#  'gadzuda01',
#  'gaffoda01',
#  'gainesu01',
#  'galemi01',
#  'gallida01',
#  'gallola01',
#  'gamblke01',
#  'garbajo01',
#  'garcifr01',
#  'garlada01',
#  'garlaga01',
#  'garlawi01',
#  'garnebi02',
#  'garneke01',
#  'garreca01',
#  'garrede01',
#  'garredi02',
#  'garripa01',
#  'garrito01',
#  'gasolma01',
#  'gasolpa01',
#  'gatlich01',
#  'gattike01',
#  'gayru01',
#  'gearyre01',
#  'geeal01',
#  'geigema01',
#  'gelabmi01',
#  'georgde01',
#  'georgma01',
#  'georgpa01',
#  'georgta01',
#  'gerargu01',
#  'gervide01',
#  'gervige01',
#  'gibsoda01',
#  'gibsota01',
#  'gilesha01',
#  'gilgesh01',
#  'gilled01',
#  'gilliar01',
#  'gillke01',
#  'gilmoar01',
#  'ginobma01',
#  'giricgo01',
#  'givenja01',
#  'glassge01',
#  'glennmi01',
#  'gloucge01',
#  'glovedi01',
#  'gminsmi01',
#  'goberru01',
#  'goldwan01',
#  'gomesry01',
#  'gondrgl01',
#  'gondrgr01',
#  'goodedr01',
#  'goodwar01',
#  'goodwbr01',
#  'gordoaa01',
#  'gordobe01',
#  'gordoer01',
#  'gordola01',
#  'gortama01',
#  'goudean01',
#  'grahade01',
#  'grahagr01',
#  'grahajo01',
#  'grahapa01',
#  'grahast01',
#  'grahatr01',
#  'grandro01',
#  'grangda01',
#  'grangst01',
#  'grantbr01',
#  'grantga01',
#  'grantgr01',
#  'grantha01',
#  'grantho01',
#  'grantje01',
#  'grantje02',
#  'grantjo01',
#  'grayaa01',
#  'grayeje01',
#  'grayst01',
#  'graysy01',
#  'greenac01',
#  'greenda01',
#  'greenda02',
#  'greendo01',
#  'greendr01',
#  'greener01',
#  'greenge01',
#  'greenja01',
#  'greenja02',
#  'greenje02',
#  'greenke02',
#  'greenli01',
#  'greenor01',
#  'greenri01',
#  'greensi02',
#  'greenwi01',
#  'greerly01',
#  'greveke01',
#  'griffad01',
#  'griffbl01',
#  'griffda01',
#  'griffed01',
#  'griffpa01',
#  'grossbo01',
#  'grunfer01',
#  'gudmupe01',
#  'gudurma01',
#  'guglito01',
#  'guytoaj01',
#  'hachiru01',
#  'haffnsc01',
#  'hairsma01',
#  'hairspj02',
#  'haleyja01',
#  'halibty01',
#  'hamda01',
#  'hamiljo02',
#  'hamilju01',
#  'hamilri01',
#  'hamilro01',
#  'hamilze01',
#  'hammoto01',
#  'hamptrj01',
#  'hancoda01',
#  'hansbty01',
#  'hansebo01',
#  'hansetr01',
#  'hanzlbi01',
#  'haranlu01',
#  'hardaan01',
#  'hardati01',
#  'hardati02',
#  'hardeja01',
#  'hardyja01',
#  'harklma01',
#  'harpede01',
#  'harpemi01',
#  'harpero01',
#  'harprma01',
#  'harremo01',
#  'harrial01',
#  'harrian01',
#  'harrida01',
#  'harride01',
#  'harriga01',
#  'harrijo01',
#  'harriju01',
#  'harrilu01',
#  'harrima01',
#  'harriot01',
#  'harrish01',
#  'harrist01',
#  'harrito02',
#  'harteis01',
#  'hartja01',
#  'hartjo01',
#  'harvean01',
#  'harvedo01',
#  'hasleud01',
#  'hassejo01',
#  'hassetr01',
#  'hastisc01',
#  'hawessp01',
#  'hawesst01',
#  'hawkihe01',
#  'hawkiju01',
#  'hayesch01',
#  'hayesel01',
#  'hayesja01',
#  'hayesja02',
#  'hayesst01',
#  'haywago01',
#  'haywala01',
#  'haywobr01',
#  'haywosp01',
#  'headlu01',
#  'healsh01',
#  'heardga01',
#  'hendeal01',
#  'hendece02',
#  'hendege01',
#  'hendege02',
#  'hendeto01',
#  'hendrma01',
#  'henryco01',
#  'henryxa01',
#  'hensojo01',
#  'hensost01',
#  'hernaju01',
#  'hernawi01',
#  'herreca01',
#  'herrech01',
#  'herrmwa01',
#  'herroke01',
#  'herroty01',
#  'hezonma01',
#  'hibbero01',
#  'hicksjj01',
#  'hieldbu01',
#  'higgiro01',
#  'higgise01',
#  'higgske01',
#  'highjo01',
#  'hilarne01',
#  'hillar01',
#  'hillge01',
#  'hillgr01',
#  'hilljo01',
#  'hillmda01',
#  'hillso01',
#  'hillty01',
#  'hinriki01',
#  'hinsoro01',
#  'hodgecr01',
#  'hodgedo01',
#  'hoibefr01',
#  'holidaa01',
#  'holidjr01',
#  'holidju01',
#  'hollabr01',
#  'hollili01',
#  'holliro01',
#  'holliry01',
#  'holmeri01',
#  'holtomi01',
#  'hoodro01',
#  'hoppeda01',
#  'hopsode01',
#  'hordgce01',
#  'horfoal01',
#  'hornaje01',
#  'horryro01',
#  'hortoed01',
#  'hortota01',
#  'houseda01',
#  'houseed01',
#  'houstal01',
#  'houstby01',
#  'howarbr01',
#  'howardw01',
#  'howarjo01',
#  'howarju01',
#  'howarst01',
#  'hubbaph01',
#  'hudsotr01',
#  'huertke01',
#  'huertma01',
#  'huestjo01',
#  'hugheed01',
#  'hugheki01',
#  'hughela01',
#  'hugheri01',
#  'hummero01',
#  'humphja01',
#  'humphkr01',
#  'humphry01',
#  'huntech01',
#  'huntede01',
#  'hunteli01',
#  'huntest01',
#  'hurlebo01',
#  'hustoge01',
#  'hutchch01',
#  'iavarma01',
#  'ibakase01',
#  'iguodan01',
#  'ilgauzy01',
#  'ilyaser01',
#  'inglejo01',
#  'ingrabr01',
#  'irvinby01',
#  'irvinky01',
#  'isaacjo01',
#  'isselda01',
#  'iuzzomi01',
#  'iversal01',
#  'iveyro01',
#  'iwundwe01',
#  'jackja01',
#  'jacksbo01',
#  'jacksda01',
#  'jacksfr01',
#  'jacksja01',
#  'jacksja02',
#  'jacksje01',
#  'jacksji01',
#  'jacksjo02',
#  'jacksju01',
#  'jacksma01',
#  'jacksma02',
#  'jacksmi02',
#  'jacksre01',
#  'jacksst02',
#  'jackstr01',
#  'jacobca01',
#  'jacobsa01',
#  'jamerda01',
#  'jamesbe01',
#  'jameshe01',
#  'jamesje01',
#  'jamesle01',
#  'jamesmi01',
#  'jamisan01',
#  'jaricma01',
#  'jasiksa01',
#  'jeelaab01',
#  'jeffeal01',
#  'jeffech01',
#  'jeffeco01',
#  'jefferi01',
#  'jeffrja01',
#  'jenkich01',
#  ...]

# %%
print(list(player_names_id_df.drop_duplicates().reset_index()["Player_ID"]))

"brownde01" in list(player_names_id_df.drop_duplicates().reset_index()["Player_ID"])
# Out:
# ['smithro01', 'smithbi02', 'pheglro01', 'paultbi01', 'nattca01', 'moneyer01', 'mcginge01', 'lucasma01', 'landsma01', 'kelleri01', 'jonesdw01', 'furlote01', 'forddo01', 'englial01', 'cleamji01', 'carrke01', 'bosweto01', 'boonero01', 'bensoke01', 'abdulka01', 'abernto01', 'adamsal01', 'architi01', 'baileja01', 'ballagr01', 'bantomi01', 'barryri01', 'beshode01', 'bibbyhe01', 'birdla01', 'birdsot01', 'boynewi01', 'bradldu01', 'bratzmi01', 'breweji01', 'brewero01', 'bridgju01', 'bristal01', 'brownfr01', 'bryanjo01', 'bucknqu01', 'busedo01', 'calvima01', 'carrau01', 'carrml01', 'cartwbi01', 'catchha01', 'chanedo01', 'cheekma01', 'cheniph01', 'choneji01', 'cookje01', 'coopemi01', 'coopewa01', 'copelho01', 'corzida01', 'cowenda01', 'crissch01', 'cummipa01', 'dandrbo01', 'dantlad01', 'davisjo01', 'daviswa03', 'dawkida01', 'dawkipa01', 'demicla01', 'dietrco01', 'douglle01', 'drewjo01', 'duerote01', 'dunlemi01', 'dunntr01', 'edwarja01', 'elliobo01', 'ellisbo02', 'elmorle01', 'ervinju01', 'evansmi01', 'fernser01', 'fordch01', 'fordph01', 'freewo01', 'galemi01', 'garlaga01', 'gerargu01', 'gervige01', 'gilmoar01', 'givenja01', 'glennmi01', 'gondrgl01', 'greenda01', 'greveke01', 'griffpa01', 'grossbo01', 'grunfer01', 'hamilro01', 'hardyja01', 'hassejo01', 'hawesst01', 'hayesel01', 'haywosp01', 'heardga01', 'hendege01', 'hendeto01', 'highjo01', 'hillar01', 'hillmda01', 'hollili01', 'hubbaph01', 'hugheki01', 'hustoge01', 'isselda01',
# True

# %% [markdown]
# #### Creating DF for the first problem

# %%
players_draft_data = pd.read_csv("data/draft_classes.csv")
players_draft_data["Years_Played"] = players_draft_data["To"] - players_draft_data["From"]
players_draft_data = players_draft_data[players_draft_data["Years_Played"] >= 10 ].reset_index()
player_list_79_99 = players_draft_data["Player"].apply(string_filter)
players_draft_data["Player"] = player_list_79_99
players_draft_data["Player_ID"] = [player_to_ID[x] for x in players_draft_data["Player"]]
players_draft_data
# Out:
#      index   Rk   Lg  Rd   Pk   Tm           Player     Age  Pos Born  ...  \
# 0        0    1  NBA   1    1  CHI       eltonbrand  20.116  F-C   us  ...
# 1        2    3  NBA   1    3  CHH       barondavis  20.083    G   us  ...
# 2        3    4  NBA   1    4  LAC        lamarodom  19.241    F   us  ...
# 3        4    5  NBA   1    5  TOR   jonathanbender  18.155    F   us  ...
# 4        6    7  NBA   1    7  WAS  richardhamilton  21.141  G-F   us  ...
# ..     ...  ...  ...  ..  ...  ...              ...     ...  ...  ...  ...
# 297    699  800  NBA   3   58  PHI      earlcureton  21.300  F-C   us  ...
# 298    700  801  NBA   3   65  CLE     billlaimbeer  22.042    C   us  ...
# 299    701  802  NBA   4   73  SEA   jamesdonaldson  21.318    C   gb  ...
# 300    705  806  NBA   5  107  PHO        markeaton  22.157    C   us  ...
# 301    706  807  NBA   8  165  PHO     charlesjones  22.088  F-C   us  ...
#
#      STL  BLK    FG%    2P%    3P%    FT%     WS  WS/48  Years_Played  \
# 0    0.9  1.7  0.500  0.501  0.095  0.736  109.6  0.151          16.0
# 1    1.8  0.4  0.409  0.456  0.320  0.711   63.1  0.106          12.0
# 2    0.9  0.9  0.463  0.502  0.312  0.693   77.0  0.115          13.0
# 3    0.2  0.6  0.417  0.442  0.340  0.763    3.8  0.047          10.0
# 4    0.8  0.1  0.449  0.463  0.346  0.852   62.8  0.102          13.0
# ..   ...  ...    ...    ...    ...    ...    ...    ...           ...
# 297  0.5  0.5  0.473  0.476  0.000  0.538   14.4  0.056          16.0
# 298  0.7  0.9  0.498  0.508  0.326  0.837  105.6  0.149          13.0
# 299  0.4  1.3  0.571  0.571    NaN  0.732   62.3  0.114          14.0
# 300  0.4  3.5  0.458  0.458  0.000  0.649   44.8  0.085          10.0
# 301  0.6  1.6  0.480  0.482  0.000  0.618   24.6  0.084          14.0
#
#      Player_ID
# 0    brandel01
# 1    davisba01
# 2     odomla01
# 3    bendejo01
# 4    hamilri01
# ..         ...
# 297  curetea01
# 298  laimbbi01
# 299  donalja01
# 300  eatonma01
# 301  jonesch03
#
# [302 rows x 29 columns]

# %%
halloffame
hall_of_fame_players = halloffame["Inductees"].apply(string_filter)

# %%
hof_df = pd.DataFrame(columns = ["Players", "Player_ID", "In_HoF"])
hof_df["Players"] = player_list_79_99
hof_df["Player_ID"] = [player_to_ID[x] for x in hof_df["Players"]]

for i in range(len(hof_df["Players"])):
    if hof_df["Players"][i] in list(hall_of_fame_players):
        hof_df.loc[i,["In_HoF"]] = 1
    else:
        hof_df.loc[i,["In_HoF"]] = 0
sum(hof_df["In_HoF"])

player_to_ID["michaeljordan"]
hof_df
# Out:
#              Players  Player_ID In_HoF
# 0         eltonbrand  brandel01      0
# 1         barondavis  davisba01      0
# 2          lamarodom   odomla01      0
# 3     jonathanbender  bendejo01      0
# 4    richardhamilton  hamilri01      0
# ..               ...        ...    ...
# 297      earlcureton  curetea01      0
# 298     billlaimbeer  laimbbi01      0
# 299   jamesdonaldson  donalja01      0
# 300        markeaton  eatonma01      0
# 301     charlesjones  jonesch03      0
#
# [302 rows x 3 columns]

# %%
player_hof_dict = {}
stat_columns = zscores_dict['1979-80'].columns[9:]
hof_data = []
for player in hof_df["Player_ID"]:
    player_hof_dict[player] = 1
    player_row = list(hof_df.loc[hof_df.Player_ID == player].values[0])
    for year in zscores_dict.keys():
        if player in list(zscores_dict[year]["Player_ID"]) and player_hof_dict[player]<11:
            player_row += list(zscores_dict[year][zscores_dict[year].Player_ID == player].values[0][9:])
            player_hof_dict[player]+= 1
    hof_data.append(player_row)

# hof_df.loc[hof_df.Players == "earlcureton"].values
# player_row = hof_df.loc[hof_df.Player_ID == 'jordami01']
# player_row.values[0]
# list(player_row.values[0]) + list(zscores_dict["1996-97"][zscores_dict["1996-97"].Player_ID == 'jordami01'].values[0][9:]
# hof_df.loc[len(hof_df.index)] = ["a", "b", 1,2,3,4]
hof_df
# Out:
#              Players  Player_ID In_HoF
# 0         eltonbrand  brandel01      0
# 1         barondavis  davisba01      0
# 2          lamarodom   odomla01      0
# 3     jonathanbender  bendejo01      0
# 4    richardhamilton  hamilri01      0
# ..               ...        ...    ...
# 297      earlcureton  curetea01      0
# 298     billlaimbeer  laimbbi01      0
# 299   jamesdonaldson  donalja01      0
# 300        markeaton  eatonma01      0
# 301     charlesjones  jonesch03      0
#
# [302 rows x 3 columns]

# %%
print("Amount of players processed: ", len(hof_data))
hof_data_correct = [x for x in hof_data if len(x) == 223]
print("Amount of players with 223 variables: ", len(hof_data_correct))
# Out:
# Amount of players processed:  302
# Amount of players with 223 variables:  230

# %%
hof_column_names = ["Players", "Player_ID", "In_HoF"]

zscore_columns = zscores_dict["2005-06"].columns[9:]

for i in range(1,11):
    temp_col = ["yr"+str(i)+"_"+ x for x in zscore_columns]
    hof_column_names += temp_col
    
print("length of column names: ", len(hof_column_names))
# Out:
# length of column names:  223

# %%
hof_df = pd.DataFrame(data = hof_data_correct, columns = hof_column_names)
hof_df
# Out:
#              Players  Player_ID  In_HoF  yr1_FG_zscore  yr1_FGA_zscore  \
# 0         eltonbrand  brandel01       0       2.095948        1.929241
# 1         barondavis  davisba01       0      -0.470179       -0.411569
# 2          lamarodom   odomla01       0       1.059187        1.173103
# 3    richardhamilton  hamilri01       0      -0.057766        0.049622
# 4        andremiller  millean02       0       0.429111        0.451823
# ..               ...        ...     ...            ...             ...
# 225    vinniejohnson  johnsvi01       0       0.502751        0.335146
# 226        jimpaxson  paxsoji02       0      -0.755662       -0.621965
# 227     billlaimbeer  laimbbi01       0       0.087096        0.036429
# 228   jamesdonaldson  donalja01       0      -0.967249       -1.085709
# 229        markeaton  eatonma01       0      -0.857098       -0.766698
#
#      yr1_FG%_zscore  yr1_3P_zscore  yr1_3PA_zscore  yr1_3P%_zscore  \
# 0          0.765244      -0.827483       -0.852307       -1.400941
# 1         -0.480631      -0.231443        0.119012       -0.108623
# 2         -0.118926       0.579171        0.591305        0.666767
# 3         -0.480631      -0.159919       -0.183968        0.689742
# 4          0.102117      -0.589067       -0.433482       -0.229240
# ..              ...            ...             ...             ...
# 225        1.148210      -0.316699       -0.380350        0.363372
# 226       -1.455804      -0.378592        0.023771       -0.734442
# 227        0.524852      -0.434507       -0.571688       -0.819610
# 228        1.309077      -0.434507       -0.571688       -0.819610
# 229       -1.283501      -0.512646       -0.596425       -0.885196
#
#      yr1_2P_zscore  ...  yr10_FT%_zscore  yr10_ORB_zscore  yr10_DRB_zscore  \
# 0         2.475149  ...         0.328496         2.577382         1.689534
# 1        -0.447166  ...         0.010180        -0.531776        -0.188147
# 2         0.992368  ...        -0.432985         1.654739         2.784631
# 3        -0.020866  ...         0.865525        -0.564388        -0.403065
# 4         0.615494  ...         0.658738         0.723785         0.204634
# ..             ...  ...              ...              ...              ...
# 225       0.519498  ...        -0.747607         0.097443        -0.449210
# 226      -0.738332  ...         0.667778        -1.123151        -1.076688
# 227       0.106431  ...         1.089215         0.891323         2.701377
# 228      -0.954285  ...        -0.431595         0.740760         1.761610
# 229      -0.845326  ...        -1.494968         0.571862         0.853840
#
#      yr10_TRB_zscore  yr10_AST_zscore  yr10_STL_zscore  yr10_BLK_zscore  \
# 0           2.062169        -0.204505         1.281332         2.100729
# 1          -0.311450         2.399395         1.731009         0.023189
# 2           2.541729         0.799190         0.725620         0.699670
# 3          -0.477915         0.994505        -0.392634        -0.848568
# 4           0.386628         2.626656         1.762239        -0.567356
# ..               ...              ...              ...              ...
# 225        -0.277296         0.407994         0.202689        -0.480827
# 226        -1.128657        -0.425721        -0.582312        -0.630030
# 227         2.172056        -0.064827        -0.126411         0.948304
# 228         1.470905        -0.706514        -0.949160         0.203545
# 229         0.775377        -0.831431        -0.602146         3.388376
#
#      yr10_TOV_zscore  yr10_PF_zscore  yr10_PTS_zscore
# 0           0.123283        1.827005         1.152037
# 1           1.659099        0.776679         0.524008
# 2           0.900084        1.363621         0.353193
# 3           0.629062        0.475017         1.075440
# 4           1.762102        0.829914         1.315753
# ..               ...             ...              ...
# 225         0.145587       -0.352612         0.038750
# 226        -0.903763       -1.045334        -0.565776
# 227        -0.232795        1.545555         0.376010
# 228         0.085046       -0.549459        -0.226104
# 229        -0.775239        1.188393        -1.013822
#
# [230 rows x 223 columns]

# %%
hof_df.to_csv("hof_data.csv")

# %% [markdown]
# #### Creating Data set for second problem

# %%
all_stars_df = pd.read_csv("data/allstars.csv")
all_stars_df.info()
all_stars_selections = [x.split(";") for x in all_stars_df["Selections[c]"]]
all_star_player = list(all_stars_df["Player"].apply(string_filter))
all_star_zip = list(zip(all_star_player, all_stars_selections))
def count_dict(key, item, dct):
    if key in dct.keys():
#         print("cont, ", key,item)
        dct[key] += [item]
    else:
#         print("start ", key,item)
        dct[key] = [item]

def year_dash_parsing(lst):
    year_and_allstars = {}
    for item in lst:
        for word in item[1]:
#             print(word)
            if "–" in word:
                years = word.split("–")
                print(years)
                list_of_years = range(int(years[0]), int(years[1]) + 1)
                [count_dict(str(x),item[0], year_and_allstars) for x in list_of_years]
            else:
                count_dict(string_filter(word),item[0], year_and_allstars)
    return year_and_allstars

# year_dash_parsing()
all_star_years = year_dash_parsing(all_star_zip)
# all_star_zip[0][1][0]
# "–" in all_star_zip[0][1][0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         437 non-null    object
#  1   #              437 non-null    int64
#  2   Selections[c]  437 non-null    object
#  3   Notes          92 non-null     object
#  4   Reference      437 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 17.2+ KB
# ['1970', '1977']
# [' 1979', '1989']
# [' 2000', '2016']
# ['2005', '2021']
# [' 2000', '2011']
# ['1997', '1998']
# [' 2000', '2011']
# ['1993', '1998']
# [' 2000', '2007']
# ['1985', '1993']
# [' 1996', '1998']
# [' 2002', '2003']
# ['1988', '1998']
# [' 2000', '2002']
# ['2002', '2012']
# [' 2014', '2015']
# ['1961', '1974']
# ['1960', '1969']
# [' 1971', '1973']
# ['1951', '1963']
# ['1966', '1978']
# ['2005', '2016']
# ['1980', '1988']
# [' 1990', '1992']
# ['1969', '1980']
# [' 1982', '1992']
# ['1978', '1989']
# ['1985', '1990']
# [' 1992', '1997']
# ['1961', '1972']
# ['1958', '1969']
# ['1951', '1962']
# ['1982', '1993']
# ['1987', '1997']
# ['1959', '1965']
# [' 1967', '1970']
# ['2006', '2016']
# ['2010', '2019']
# ['1977', '1987']
# [' 1988', '1997']
# ['2000', '2010']
# ['2008', '2016']
# [' 2020', '2021']
# ['1955', '1965']
# ['2000', '2002']
# [' 2004', '2009']
# ['2007', '2008']
# [' 2010', '2017']
# ['1951', '1952']
# [' 1955', '1962']
# [' 1988', '1994']
# [' 1996', '1997']
# ['1961', '1970']
# [' 2000', '2004']
# [' 2007', '2008']
# ['2002', '2006']
# [' 2008', '2012']
# ['1990', '1996']
# [' 2000', '2001']
# ['1989', '1997']
# ['1977', '1985']
# ['2013', '2021']
# ['1981', '1987']
# [' 1990', '1991']
# ['1994', '1998']
# [' 2000', '2003']
# ['2011', '2013']
# [' 2015', '2020']
# ['1963', '1965']
# [' 1967', '1971']
# ['1986', '1994']
# ['1966', '1967']
# [' 1973', '1978']
# ['2000', '2007']
# ['1972', '1978']
# ['2014', '2021']
# ['1966', '1968']
# [' 1970', '1974']
# ['1982', '1989']
# ['1951', '1956']
# [' 1958', '1959']
# ['2007', '2014']
# ['1972', '1975']
# [' 1977', '1979']
# [' 1995', '1998']
# [' 2000', '2002']
# ['2002', '2003']
# [' 2005', '2008']
# ['1953', '1960']
# ['2003', '2009']
# ['2012', '2016']
# [' 2018', '2019']
# ['1968', '1969']
# [' 1973', '1976']
# ['2014', '2019']
# ['1970', '1976']
# ['1951', '1957']
# ['2013', '2014']
# [' 2016', '2019']
# ['1995', '1998']
# [' 2000', '2001']
# ['2013', '2015']
# [' 2017', '2019']
# ['2007', '2012']
# ['1964', '1969']
# ['1951', '1957']
# ['1953', '1959']
# ['2001', '2007']
# ['1951', '1952']
# [' 1954', '1956']
# [' 1958', '1959']
# [' 1986', '1991']
# ['1994', '1997']
# [' 2000', '2002']
# [' 1992', '1997']
# ['1965', '1971']
# ['1979', '1985']
# ['1965', '1968']
# [' 1973', '1974']
# [' 1966', '1967']
# [' 1970', '1971']
# [' 1973', '1974']
# ['1971', '1977']
# ['1986', '1992']
# [' 1975', '1976']
# [' 1980', '1982']
# ['1958', '1962']
# ['1980', '1982']
# [' 1984', '1986']
# ['1978', '1981']
# ['1990', '1993']
# [' 2009', '2011']
# [' 2015', '2016']
# ['1978', '1979']
# [' 1981', '1983']
# ['2011', '2015']
# ['1958', '1963']
# [' 1961', '1965']
# ['1961', '1964']
# [' 1966', '1967']
# ['1969', '1974']
# ['1953', '1958']
# ['1993', '1998']
# ['2014', '2015']
# [' 2018', '2021']
# ['2015', '2020']
# ['1951', '1953']
# [' 1955', '1957']
# ['2002', '2007']
# ['2006', '2007']
# [' 2012', '2014']
# ['1993', '1998']
# [' 2007', '2011']
# ['1957', '1960']
# [' 1962', '1963']
# ['1955', '1960']
# ['2017', '2021']
# ['2006', '2010']
# ['1953', '1957']
# ['2015', '2018']
# ['1988', '1989']
# [' 1991', '1993']
# ['1961', '1965']
# ['1960', '1964']
# [' 1972', '1975']
# ['1958', '1962']
# ['1991', '1993']
# [' 1997', '1998']
# ['2010', '2011']
# [' 2015', '2016']
# ['1979', '1982']
# [' 1968', '1971']
# ['1979', '1981']
# [' 1964', '1966']
# ['1962', '1963']
# [' 1968', '1969']
# ['2016', '2017']
# [' 2019', '2021']
# ['2011', '2012']
# [' 2017', '2018']
# ['1973', '1974']
# [' 1977', '1979']
# ['1974', '1978']
# [' 1995', '1996']
# ['1982', '1986']
# ['1989', '1993']
# ['1963', '1967']
# ['1951', '1955']
# ['1958', '1962']
# ['2015', '2019']
# ['1974', '1977']
# [' 1971', '1973']
# ['2014', '2018']
# ['1952', '1956']
# [' 2000', '2003']
# ['1977', '1981']
# ['1995', '1998']
# ['1962', '1965']
# ['1979', '1981']
# ['1985', '1987']
# [' 1989', '1991']
# [' 1986', '1988']
# ['1976', '1979']
# ['2015', '2018']
# ['1969', '1972']
# [' 1975', '1976']
# ['1951', '1954']
# [' 2016', '2018']
# ['2018', '2021']
# ['1957', '1960']
# ['1962', '1963']
# ['1995', '1998']
# ['1970', '1973']
# ['1972', '1975']
# ['1953', '1954']
# [' 1956', '1957']
# ['1977', '1978']
# [' 1981', '1982']
# [' 1984', '1985']
# ['1983', '1985']
# ['1956', '1957']
# [' 1960', '1961']
# ['1977', '1979']
# [' 2005', '2007']
# ['1951', '1954']
# ['2014', '2017']
# [' 1960', '1962']
# ['1951', '1952']
# [' 1954', '1955']
# [' 1992', '1994']
# ['1980', '1982']
# ['1952', '1955']
# ['1986', '1988']
# ['1963', '1964']
# [' 1966', '1967']
# ['2010', '2013']
# ['1984', '1987']
# ['1994', '1995']
# ['1977', '1979']
# ['2017', '2020']
# ['2003', '2006']
# ['2000', '2001']
# ['1972', '1975']
# [' 1987', '1988']
# ['2005', '2007']
# ['2018', '2019']
# ['1967', '1968']
# ['1974', '1975']
# ['1963', '1965']
# ['2002', '2004']
# ['2016', '2018']
# ['2006', '2008']
# ['1990', '1991']
# ['2019', '2021']
# ['1997', '1998']
# ['1971', '1973']
# ['1971', '1973']
# ['1992', '1993']
# ['1976', '1977']
# ['1969', '1971']
# ['1996', '1998']
# ['2010', '2012']
# ['1980', '1982']
# ['2008', '2010']
# ['1973', '1975']
# ['1953', '1955']
# ['2019', '2021']
# ['2002', '2004']
# ['1956', '1958']
# ['1969', '1971']
# ['1970', '1972']
# [' 1976', '1977']
# [' 2002', '2003']
# ['1982', '1983']
# ['2010', '2012']
# ['1952', '1953']
# ['2020', '2021']
# ['2007', '2008']
# ['1996', '1997']
# ['1951', '1952']
# ['2007', '2008']
# ['1969', '1970']
# ['2012', '2013']
# ['2020', '2021']
# ['1960', '1961']
# ['1951', '1952']
# ['2000', '2001']
# ['1951', '1952']
# ['1956', '1957']
# ['2020', '2021']
# ['2000', '2001']
# ['1960', '1961']
# ['1980', '1981']
# ['1971', '1972']
# ['1978', '1979']
# ['1968', '1969']
# ['1986', '1987']
# ['1993', '1994']
# ['1972', '1973']
# ['2019', '2020']
# ['2003', '2004']
# ['2020', '2021']
# ['2013', '2014']
# ['2018', '2019']
# ['1983', '1984']
# ['2000', '2001']
# ['1951', '1952']
# ['1984', '1985']
# ['2020', '2021']
# ['1952', '1953']
# ['1958', '1959']
# ['1976', '1977']
# ['2000', '2001']
# ['2020', '2021']
# ['2016', '2017']
# ['1983', '1984']
# ['2018', '2019']
# ['1983', '1984']
# ['1977', '1978']
# ['2008', '2009']
# ['1982', '1983']

# %%
all_star_player_ids = []
keys_all_star_years = list(seasons_dict.keys())[:35]

for key in keys_all_star_years:
    all_star_player_ids += list(zscores_dict[key]["Player_ID"])
    
all_star_player_ids = np.unique(all_star_player_ids)
all_star_player_ids
# Out:
# array(['abdelal01', 'abdulka01', 'abdulma02', ..., 'zellety01',
#        'zhizhwa01', 'zidekge01'], dtype='<U9')

# %%
all_star_player_dict = {}
stat_columns = zscores_dict['1979-80'].columns[9:]
all_star_data = []


for player in all_star_player_ids:
    all_star_player_dict[player] = 1
    player_name = ID_to_Player[player]
    
    
    player_row = [player_name, player]
    for year in keys_all_star_years:
        if player in list(zscores_dict[year]["Player_ID"]) and all_star_player_dict[player]<3:
            player_row += list(zscores_dict[year][zscores_dict[year].Player_ID == player].values[0][9:])
            player_row += [year]
            all_star_player_dict[player]+= 1
    all_star_data.append(player_row)

all_star_data
# Out:
# [['alaaabdelnaby',
#   'abdelal01',
#   '1990-91',
#   -1.2950339608228492,
#   -1.3499718938903542,
#   0.10739600386904238,
#   -0.5910638099145727,
#   -0.6540397042739666,
#   -1.2320257359948863,
#   -1.268051448547628,
#   -0.319496726128344,
#   -1.0532608088944369,
#   0.020704487086248637,
#   0.07352591783109289,
#   0.6696994062421954,
#   -0.4791450580447033,
#   -0.36187460341228184,
#   -1.014202902201398,
#   -0.9604182606512588,
#   -0.793112660163585,
#   -0.7425410820622456,
#   -1.11389554913396,
#   0.21132351468836402,
#   -0.7545717953189127,
#   -0.4545792588875986,
#   -0.6726343421498212,
#   -0.33616491079161215,
#   -0.43551096572863984,
#   -0.669377286851978,
#   -0.21102206700245724,
#   -0.5390793806858696,
#   '1990-91',
#   '1991-92',
#   -0.12200398954023628,
#   -0.019815864585073766,
#   -0.47716156608723265,
#   -0.037722806663694416,
#   -0.05579970160427826,
#   0.7684425876084117,
#   -0.12290469094816805,
#   -0.008505304786705735,
#   -0.5657345747106319,
#   -0.4739378854256792,
#   -0.1395944328674238,
#   -0.09166252985347875,
#   -0.1438592673099336,
#   0.4979153782436476,
#   -0.30863584612448647,
#   -0.028976932766811934,
#   -0.7220438571745322,
#   0.08852351027143475,
#   -0.22103060258058974,
#   -0.295792979353691,
#   0.10003141416916303,
#   -0.12827288370000534,
#   '1991-92'],
#  ...]

# %%
zscores_dict['1979-80'].columns[8:]
zscores_dict["1979-80"]["Year"][0]
zscores_dict['1979-80'].columns
all_star_data[0]
# Out:
# ['alaaabdelnaby',
#  'abdelal01',
#  '1990-91',
#  -1.2950339608228492,
#  -1.3499718938903542,
#  0.10739600386904238,
#  -0.5910638099145727,
#  -0.6540397042739666,
#  -1.2320257359948863,
#  -1.268051448547628,
#  -1.316768039165294,
#  -0.16698499940634579,
#  -0.1548072842735033,
#  -1.0598549586291293,
#  -1.061660936297809,
#  -1.718372783674928,
#  -1.057196806465178,
#  -1.0415552505626995,
#  -1.083304067074896,
#  -0.9723285776380364,
#  -1.3412956470845216,
#  -0.5914101625674034,
#  -1.440632740248507,
#  -1.8530282770019426,
#  -1.2782202696653566,
#  '1990-91',
#  '1991-92',
#  -0.638129236921244,
#  -0.706303555594228,
#  0.5687202429748169,
#  -0.5930069199144028,
#  -0.6664301871043017,
#  -1.1819251924322411,
#  -0.5744611246776361,
#  -0.6168491804138183,
#  0.3047417856951488,
#  0.28681033120416255,
#  -0.6329468908703164,
#  -0.6562931252727943,
#  0.10557611517248064,
#  -0.27852387855415983,
#  -0.2101209292738318,
#  -0.23995504999034098,
#  -0.8922013247630441,
#  -0.8553913623864112,
#  -0.4876345252808887,
#  -0.6793498934583133,
#  -0.3853190265595338,
#  -0.6735413452586717,
#  '1991-92']

# %%
print("length of all star data: ", len(all_star_data))
all_star_data = [x for x in all_star_data if len(x) == 50]
print("length of all star data after cleaning: ", len(all_star_data))
# Out:
# length of all star data:  1878
# length of all star data after cleaning:  1505

# %%
for player in all_star_data:
    year = player[-1][:2]
    year = year[:2] + year[5:]
    if year == '1900':
        year = '2000'
    all_star_years = range(int(year) + 1,int(year) + 5)
    for yr in all_star_years:
        
    
'1991-92'[:2] + '1991-92'[5:]

'1999-00'[:2] + '1999-00'[5:]
# Out:
# '1900'
